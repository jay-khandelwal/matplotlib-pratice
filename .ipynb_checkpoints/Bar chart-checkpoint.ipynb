# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
country = ['india','china','pakistan','usa','france']

# %%
popular = [29393939,83383838,28383848,3848587,76949]

# %%
plt.title(' population of 5 countries ')
# Out:
# Text(0.5, 1.0, ' population of 5 countries ')

# %%
plt.xlabel('country')
plt.ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %%
plt.barh(country, popular,linewidth=.025, color='#4facfe')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.show()
