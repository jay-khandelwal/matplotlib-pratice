# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.arange(10,15,1.3)

# %%
y = np.tan(x)

# %%
plt.plot(x,y, color='#1facfe')
plt.title('tan')
plt.xlabel('x')
plt.ylabel('y')
plt.legend('gray')
